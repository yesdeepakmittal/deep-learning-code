# %% [markdown]
# <a href="https://colab.research.google.com/github/yesdeepakmittal/deep-learning-code/blob/main/Deep_Learning_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ReLu

# %%
import matplotlib.pyplot as plt
import numpy as np


def relu(arr):
    result = []

    for value in arr:
        if value > 0:
            result.append(value)
        else:
            result.append(0)

    return result

my_arr = np.arange(-10, 10, 1)

plt.plot(my_arr, relu(my_arr), label='ReLU', color='b', marker='o', markersize=5,
         linestyle='-', markerfacecolor='red', markeredgecolor='red')

# Add axes at origin
plt.axhline(0, color='black', linewidth=1)
plt.axvline(0, color='black', linewidth=1)

# Adjust the spines
ax = plt.gca()
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.legend()
plt.title('ReLU Activation Function')
plt.xlabel('Input')
plt.ylabel('Output')
plt.show()

# %% [markdown]
# # Sigmoid Activation

# %%
import matplotlib.pyplot as plt
import numpy as np

def sigmoid(arr):
    return [1 / (1 + np.exp(-value)) for value in arr]

my_arr = np.arange(-10, 10, 1)

plt.plot(my_arr, sigmoid(my_arr), label='Sigmoid', color='b', marker='o', markersize=5,
         linestyle='-', markerfacecolor='red', markeredgecolor='red')

# Add axes at origin
plt.axhline(0, color='black', linewidth=1)
plt.axvline(0, color='black', linewidth=1)

# Adjust the spines
ax = plt.gca()
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.legend()
plt.title('Sigmoid Activation Function')
plt.xlabel('Input')
plt.ylabel('Output')
plt.show()

# %% [markdown]
# # Softmax Activation

# %%
ex = np.exp(1)
ex
# Out:
# 2.718281828459045

# %%
output_layer_result = [-2.3, 1.4, 3]

ex_output_layer_result = [ex ** i for i in output_layer_result]
ex_output_layer_result
# Out:
# [0.10025884372280376, 4.055199966844674, 20.085536923187664]

# %%
norm_ex_output_layer_result = [i / sum(ex_output_layer_result) for i in ex_output_layer_result]
norm_ex_output_layer_result
# Out:
# [0.004135921016775526, 0.16728685617471903, 0.8285772228085054]

# %%
sum(norm_ex_output_layer_result)
# Out:
# 1.0
